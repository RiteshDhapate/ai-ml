# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the CSV data into a DataFrame
df = pd.read_csv('college.csv')

# Drop any rows with missing values if necessary
df = df.dropna()

# Define a function to create pie charts
def plot_pie(data, title):
    data.plot(kind='pie', figsize=(10, 6), autopct='%1.1f%%', startangle=140)
    plt.title(title)
    plt.ylabel('')  # Hide the y-label
    plt.show()

# Total students
total_students = len(df)
print("Total students:", total_students)

# Plot for 'Faculty'
faculty_counts = df['Faculty'].value_counts()
print(faculty_counts)
plot_pie(faculty_counts, 'Faculty Distribution')

# Plot for 'Are you currently taking any add-on or extra cocurricular courses outside of your major requirements?'
add_on_courses_counts = df['Are you currently taking any add-on or extra cocurricular courses outside of your major requirements?'].value_counts()
print(add_on_courses_counts)
plot_pie(add_on_courses_counts, 'Currently Taking Add-on or Extra Cocurricular Courses')

# Plot for 'Do you prefer courses that are more theoretical or practical in nature?'
preference_courses_counts = df['Do you prefer courses that are more theoretical or practical in nature?'].value_counts()
print(preference_courses_counts)
plot_pie(preference_courses_counts, 'Preference for Theoretical vs Practical Courses')

# Plot for 'Are you interested to learn add on courses?'
interest_in_add_on_courses_counts = df['Are you interested to learn add on courses?'].value_counts()
print(interest_in_add_on_courses_counts)
plot_pie(interest_in_add_on_courses_counts, 'Interest in Add-on Courses')

# Plot for 'Which Programming Languages are you Proficient in?'
programming_languages_counts = df['Which Programming Languages are you Proficient in?'].str.split(';').explode().value_counts()
print(programming_languages_counts)
plot_pie(programming_languages_counts, 'Proficiency in Programming Languages')

# Plot for 'Interested in'
interested_in_counts = df['Interested in'].str.split(';').explode().value_counts()
print(interested_in_counts)
plot_pie(interested_in_counts, 'Interest')

# Plot for 'What are your Primary areas of interest within computer Science field?'
areas_of_interest_counts = df['What are your Primary areas of interest within computer Science field?'].str.split(';').explode().value_counts()
print(areas_of_interest_counts)
plot_pie(areas_of_interest_counts, 'Primary Areas of Interest within Computer Science Field')

# Plot for 'Do you have any background knowledge in '
background_knowledge_counts = df['Do you have any background knowledge in'].value_counts()
print(background_knowledge_counts)
plot_pie(background_knowledge_counts, 'Background Knowledge')
# Out:
# Total students: 561
# Faculty
# Science     302
# Commerce    259
# Name: count, dtype: int64
# Are you currently taking any add-on or extra cocurricular courses outside of your major requirements?
# No     311
# Yes    250
# Name: count, dtype: int64
# Do you prefer courses that are more theoretical or practical in nature?
# Both           354
# Practical      171
# Theoretical     36
# Name: count, dtype: int64
# Are you interested to learn add on courses?
# Yes    534
# No      27
# Name: count, dtype: int64
# Which Programming Languages are you Proficient in?
# C/C++         395
# Python        226
# Java          182
# JavaScript    143
# Angular JS     44
# Name: count, dtype: int64
# Interested in
# Web Development                    415
# Android App Development            243
# Application Development            204
# Windows Application Development    124
# Utility Software                    87
# Name: count, dtype: int64
# What are your Primary areas of interest within computer Science field?
# Web Developement        280
# Data Science            231
# CyberSecurity           221
# Software Engineering    198
# AI/ML                   174
# Name: count, dtype: int64
# Do you have any background knowledge in
# C/C++                                                                            183
# C/C++;Operating System;Data Structure;Software Engineering                        91
# C/C++;Data Structure                                                              40
# C/C++;Operating System;Data Structure                                             37
# Data Structure                                                                    34
# C/C++;Operating System                                                            32
# Operating System                                                                  23
# Software Engineering                                                              21
# C/C++;Operating System;Data Structure;Angular JS;Node JS;Software Engineering     20
# C/C++;Data Structure;Software Engineering                                         13
# C/C++;Operating System;Software Engineering                                       10
# Operating System;Data Structure                                                    8
# C/C++;Software Engineering                                                         7
# Operating System;Data Structure;Software Engineering                               6
# Operating System;Software Engineering                                              5
# C/C++;Operating System;Data Structure;Node JS                                      4
# Node JS                                                                            3
# C/C++;Operating System;Data Structure;Angular JS;Software Engineering              3
# Angular JS                                                                         3
# C/C++;Operating System;Data Structure;Node JS;Software Engineering                 3
# C/C++;Operating System;Data Structure;Angular JS;Node JS                           2
# Angular JS;Node JS                                                                 2
# Operating System;Angular JS;Node JS                                                1
# C/C++;Node JS;Software Engineering                                                 1
# C/C++;Angular JS;Node JS                                                           1
# C/C++;Node JS                                                                      1
# Operating System;Data Structure;Angular JS;Node JS                                 1
# C/C++;Data Structure;Node JS                                                       1
# C/C++;Operating System;Node JS;Software Engineering                                1
# C/C++;Operating System;Angular JS;Software Engineering                             1
# C/C++;Data Structure;Node JS;Software Engineering                                  1
# Data Structure;Angular JS;Node JS                                                  1
# C/C++;Data Structure;Angular JS;Software Engineering                               1
# Name: count, dtype: int64
