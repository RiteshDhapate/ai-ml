# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
# Example aggregated data (replace with your actual aggregated data)
categories = ['Theoretical', 'Practical']
theoretical_data = 60  # Percentage or count of students preferring theoretical
practical_data = 40    # Percentage or count of students preferring practical

languages = ['Python', 'Java', 'C++']
language_data = [70, 50, 30]  # Percentage or count of students proficient in each language

interest_areas = ['AI', 'Software Eng.', 'Data Science']
interest_data = [45, 35, 20]  # Percentage or count of students interested in each area

# %%
languages = ['Python', 'Java', 'C++']
language_data = [70, 50, 30]  # Percentage or count of students proficient in each language

interest_areas = ['AI', 'Software Eng.', 'Data Science']
interest_data = [45, 35, 20]

# %%
# Combine all data into one list
combined_data = [theoretical_data, practical_data] + language_data + interest_data

# Define labels for the combined chart
combined_labels = categories + languages + interest_areas

# Plotting
plt.figure(figsize=(10, 6))
plt.barh(np.arange(len(combined_data)), combined_data, color=['b', 'r', 'g', 'g', 'g', 'r', 'r'])
plt.yticks(np.arange(len(combined_labels)), combined_labels)
plt.xlabel('Percentage')
plt.title('Combined Student Interests')

plt.tight_layout()
plt.show()
